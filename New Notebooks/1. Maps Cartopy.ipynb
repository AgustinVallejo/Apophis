# %% [markdown]
# # Maps with Cartopy

# %% [markdown]
# ## Importing Libraries and Data

# %%
import pandas as pd
import numpy as np
import datetime
import dateutil.parser as dparser


"ASTROPY"
from astropy.time import Time
from astropy.table import Table
from astropy.coordinates import SkyCoord, EarthLocation, AltAz, get_sun
import astropy.units as u

"CARTOPY"
import cartopy.crs as ccrs
from cartopy.feature.nightshade import Nightshade

"MATPLOTLIB"
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
from pylab import cm

mpl.rcParams['font.family'] = 'Latin Modern Roman'
plt.rcParams['font.size'] = 20
plt.rcParams['axes.linewidth'] = 2

# %%
ephemeris = pd.read_csv("../ephemeris2.csv")

# %%
continents = ['Africa',	'Antarctica','Asia','Australia','Europe','North America','South America',
              'Arctic Ocean','Atlantic Ocean','Indian Ocean','Pacific Ocean']
radio = []

for continent in continents:
  try:
    cont = pd.read_excel("../AllRadiotelescopes.xlsx",sheet_name=continent,index_col=0)
    radio.append(cont)
  except:
    pass

# %% [markdown]
# ## Create Trajectory

# %%
def get_lon(TIME,RA):
  """
  Gets the longitude that will be under the asteroid at every moment
  """
  T = Time(TIME,format='jd')
  G = T.sidereal_time('apparent', 'greenwich').to(u.deg)
  return RA - G.value

maxlons = get_lon(ephemeris['datetime_jd'],ephemeris['RA'])
maxlats = ephemeris['DEC']
deltas = ephemeris['delta (Rt)']

for i in range(len(maxlons)):
  if maxlons[i] < -180: maxlons[i] += 360

for i in range(len(maxlons)-1):
  if maxlons[i+1] > maxlons[i]:
    j = i + 1

def add_nan(array,idx):
    """
    Adds a np.nan in the location idx to split the path into two.
    """
    return list(array[:idx])+[np.nan]+list(array[idx:])

maxlons = add_nan(maxlons,j) #np.insert(maxlons,j,[-180])
maxlats = add_nan(maxlats,j) #np.insert(maxlats,j,[maxlats[j]])
deltas = add_nan(deltas,j) # np.insert(deltas,j,[deltas[j]])
# Out:
# C:\Users\agustin.vallejo\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\erfa\core.py:154: ErfaWarning: ERFA function "utcut1" yielded 200 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),
# C:\Users\agustin.vallejo\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\erfa\core.py:154: ErfaWarning: ERFA function "utctai" yielded 200 of "dubious year (Note 3)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),

# %%
def draw(ax,t,i,text=False,arrow=False):
    date = dparser.parse(ephemeris['datetime_str'][t])
    labels = list('abcdefghi')
    ax.set_global()
    ax.coastlines()
    # ax.stock_img()
    ax.add_feature(Nightshade(date, alpha=0.2))
    ax.set_title(
        "({}) {} UT \n Distance: {:.1f} $R_\oplus$".format(
        labels[i], str(ephemeris['datetime_str'][t]), ephemeris['delta (Rt)'][t]),
        size=15)

    # Contorno blanco
    plt.plot(maxlons,maxlats,'b-',lw=5,transform=data_crs)
    plt.plot(maxlons[t],maxlats[t],'bo',ms=15,transform=data_crs)

    # Relleno azul
    plt.plot(maxlons,maxlats,'w-',lw=2,transform=data_crs)
    plt.plot(maxlons[t],maxlats[t],'wo',ms=12,transform=data_crs)

    if arrow:
        plt.arrow(maxlons[t],maxlats[t]+10,0,-10,'wo',ms=12,transform=data_crs)


    # for rad in radio:
    for r,row in radio.iterrows():
        if row.Power is not np.nan:
            plt.plot(row.Longitude,row.Latitude,'r*',ms=15,transform=data_crs)
        else:
            plt.plot(row.Longitude,row.Latitude,'ro',ms=10,transform=data_crs)
        if text:
            plt.text(row.Longitude+1,row.Latitude,row.Name,transform=data_crs,fontsize=15,rotation=30)
        # plt.annotate(str(r),(row.Longitude+5,row.Latitude),size=10)
    if text:
        plt.plot(row.Longitude,row.Latitude,'ro',ms=10,transform=data_crs,label="Recievers")
        plt.plot(row.Longitude,row.Latitude,'r*',ms=10,transform=data_crs,label="Transmitters")
        plt.legend(loc=3)

# %%
radio = pd.read_csv("../AllRadiotelescopes.csv").dropna(how='all')


data_crs = ccrs.Geodetic()

t = ephemeris['delta'].idxmin()
t = int(0.93*len(ephemeris))

fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(1, 1, 1, projection=ccrs.Robinson())
draw(ax,t,0,True)

# %%
data_crs = ccrs.Geodetic()

t = ephemeris['delta'].idxmin()
t = int(0.9*len(ephemeris))
date = dparser.parse(ephemeris['datetime_str'][t])

fig = plt.figure(figsize=(20, 10))
N = 4
ts = [0,0.5,0.555,0.93]
for i in range(N):
    ax = fig.add_subplot(2, 2, i+1, projection=ccrs.Robinson())
    t = int(ts[i]*len(ephemeris))
    draw(ax,t,i)

name = "../Figures/fig2_maps_bw"
plt.savefig(name+".pdf",bbox_inches='tight')
plt.savefig(name+".png",bbox_inches='tight')
# Out:
# 'lmroman10-regular.otf' can not be subsetted into a Type 3 font. The entire font will be embedded in the output.

# %% [markdown]
# ## Usando Gridspecs

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
data_crs = ccrs.Geodetic()

t = ephemeris['delta'].idxmin()
t = int(0.9*len(ephemeris))
date = dparser.parse(ephemeris['datetime_str'][t])

fig = plt.figure(figsize=(15, 15),constrained_layout=True)
gs = fig.add_gridspec(3, 2)

ts = [0.1,0.45,0.5,0.555,0.93]
positions = [(0,0),(0,1),(1,0),(2,0),(2,1)]
for i,tt in enumerate(ts):
    row,col = positions[i]
    if row != 1:
        ax = fig.add_subplot(gs[row,col], projection=ccrs.Robinson())
    else:
        ax = fig.add_subplot(gs[row,:], projection=ccrs.Robinson())
    t = int(tt*len(ephemeris))
    draw(ax,t,i) #,arrow=True if i==4 else False)
    plt.arrow(0,0+10,0,-10,color=0) #,'wo',ms=12,transform=data_crs)

# name = "../Figures/fig2_maps_bw"
# plt.savefig(name+".pdf",bbox_inches='tight')
# plt.savefig(name+".png",bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-127-033449bbf2c7> in <module>
#      18     t = int(tt*len(ephemeris))
#      19     draw(ax,t,i) #,arrow=True if i==4 else False)
# ---> 20     plt.arrow(0,0,0,-10,color='b', projection=ccrs.Robinson()) #,'wo',ms=12,transform=data_crs)
#      21
#      22 # name = "../Figures/fig2_maps_bw"
#
# ~\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\matplotlib\pyplot.py in arrow(x, y, dx, dy, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.arrow)
#    2436 def arrow(x, y, dx, dy, **kwargs):
# -> 2437     return gca().arrow(x, y, dx, dy, **kwargs)
#    2438
#    2439
#
# ~\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\matplotlib\axes\_axes.py in arrow(self, x, y, dx, dy, **kwargs)
#    4992         dy = self.convert_yunits(dy)
#    4993
# -> 4994         a = mpatches.FancyArrow(x, y, dx, dy, **kwargs)
#    4995         self.add_patch(a)
#    4996         self._request_autoscale_view()
#
# ~\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\matplotlib\patches.py in __init__(self, x, y, dx, dy, width, length_includes_head, head_width, head_length, shape, overhang, head_starts_at_zero, **kwargs)
#    1338             verts = np.dot(coords, M) + (x + dx, y + dy)
#    1339
# -> 1340         super().__init__(verts, closed=True, **kwargs)
#    1341
#    1342
#
# ~\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\matplotlib\patches.py in __init__(self, xy, closed, **kwargs)
#    1018         %(Patch)s
#    1019         """
# -> 1020         Patch.__init__(self, **kwargs)
#    1021         self._closed = closed
#    1022         self.set_xy(xy)
#
# ~\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\matplotlib\patches.py in __init__(self, edgecolor, facecolor, color, linewidth, linestyle, antialiased, hatch, fill, capstyle, joinstyle, **kwargs)
#      93
#      94         if len(kwargs):
# ---> 95             self.update(kwargs)
#      96
#      97     def get_verts(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\apophis\lib\site-packages\matplotlib\artist.py in update(self, props)
#     994                     func = getattr(self, f"set_{k}", None)
#     995                     if not callable(func):
# --> 996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
#     998                     ret.append(func(v))
#
# AttributeError: 'FancyArrow' object has no property 'projection'
